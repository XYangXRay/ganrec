# %%
import tifffile
from fresnel import propagate
import matplotlib.pyplot as plt

# %%
energy = 15
z = 0.01
pv = 1e-8
img_f = tifffile.imread('../examples/test_results/phase_shepp.tiff')
img_a = img_f
ifp = propagate(img_f, img_a, energy, z, pv)
plt.imshow(img_f)
plt.show()
plt.imshow(ifp)
plt.show()
