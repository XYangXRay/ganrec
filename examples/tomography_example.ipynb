# %% [markdown]
# # Import necessary modules

# %%
# %matplotlib inline
import numpy as np
import tifffile
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import matplotlib.pyplot as plt
from ganrectf.utils import angles, nor_tomo
from ganrectf.ganrec import GANtomo

# %% [markdown]
# # Read the data

# %%
prj = tifffile.imread('./test_data/tooth.tiff')
nang, px = prj.shape
ang = angles(nang)
prj = nor_tomo(prj)

# %% [markdown]
# # Reconstruct the data with the ganrec algorithm

# %%
rec = GANtomo(prj, ang, iter_num=1000).recon
plt.imshow(rec)
plt.show()
tifffile.imwrite('./test_results/recon_tooth', rec)
# Out:
# Iteration 100: G_loss is 1.6819441318511963 and D_loss is 1.3871804475784302
# Iteration 200: G_loss is 1.4970794916152954 and D_loss is 1.3912214040756226
# Iteration 300: G_loss is 1.412947177886963 and D_loss is 1.382131576538086
# Iteration 400: G_loss is 1.8048123121261597 and D_loss is 1.383283257484436
# Iteration 500: G_loss is 1.3428618907928467 and D_loss is 1.387305736541748
# Iteration 600: G_loss is 1.3758403062820435 and D_loss is 1.3835227489471436
# Iteration 700: G_loss is 1.2943096160888672 and D_loss is 1.3794505596160889
# Iteration 800: G_loss is 1.283378005027771 and D_loss is 1.384189486503601
# Iteration 900: G_loss is 1.2729549407958984 and D_loss is 1.3822206258773804
# Iteration 1000: G_loss is 1.2627394199371338 and D_loss is 1.376200795173645
