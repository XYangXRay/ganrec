# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tifffile
from ganrec.propagators import TomoRadon

# %%
def tfnor_tomo(img):
    # img = tf.image.per_image_standardization(img)
        # img = img / tf.reduce_max(img)
        # img = img - tf.reduce_min(img)
    img = (img - tf.reduce_min(img)) / (tf.reduce_max(img) - tf.reduce_min(img))
    return img

# %%
strain_tensor = np.load('/nsls2/users/xyang4/data_tmp/tensor_tomography/strain_tensor.npy')
print(strain_tensor.shape)
plt.imshow(strain_tensor[0,0,:,:])
plt.show()
tifffile.imwrite('/nsls2/users/xyang4/data_tmp/tensor_tomography/strain_tensor.tiff', strain_tensor)
# plt.imshow(strain_)
# Out:
# (6, 1, 128, 128)

# %%
num_angles = 180
  # Out of plane rotation
psi = 90

    # Convert from degree to radian
angles = np.linspace(0, 180, num_angles)
angles = angles * np.pi / 180
psi = psi * np.pi / 180
num_ang = len(angles)
detector_rows = strain_tensor.shape[1]
detector_columns = strain_tensor.shape[2]

# %%
strain_tensor = np.load('/nsls2/users/xyang4/data_tmp/tensor_tomography/strain_tensor.npy')
print(strain_tensor.shape)
plt.imshow(strain_tensor[0,0,:,:])
plt.show()
num_angles = 180
  # Out of plane rotation
psi = 90

    # Convert from degree to radian
angles = np.linspace(0, 180, num_angles)
angles = angles * np.pi / 180
psi = psi * np.pi / 180
num_ang = len(angles)
detector_rows = strain_tensor.shape[1]
# print(f'')
detector_columns = strain_tensor.shape[2]
vol_mask = tf.zeros((detector_rows, detector_columns, detector_columns))
vol_mask = tf.reduce_sum(tf.abs(strain_tensor), axis=0) > 0.0
# vol_mask = 1 * (tf.reduce_sum(tf.abs(strain_tensor), axis=0) > 0.0)
# vol_mask = np.zeros((detector_rows, detector_columns, detector_columns))
# vol_mask = 1 * (np.sum(np.absolute(strain_tensor), axis=0) > 0.0)
print(vol_mask.shape)
vol_mask = tf.reshape(vol_mask, (-1, detector_columns, detector_columns, 1))
print(vol_mask.shape)
# vol_mask = np.reshape(vol_mask, (vol_mask.shape[0], vol_mask.shape[1], vol_mask.shape[2], 1))
vol_mask = tf.cast(vol_mask, dtype=tf.float32)
strain_tensor = tf.cast(strain_tensor, dtype=tf.float32)
angles = tf.cast(angles, dtype=tf.float32)
thickness = TomoRadon(vol_mask, angles).compute()
thickness = tf.squeeze(thickness)
tifffile.imwrite('/nsls2/users/xyang4/data_tmp/tensor_tomography/thickness_tf.tiff', thickness.numpy())
strain_tensor = tf.transpose(strain_tensor, [0, 2, 3, 1])
proj_strain_comp = TomoRadon(strain_tensor, angles).compute()
proj_strain_comp = tf.squeeze(proj_strain_comp)
print(proj_strain_comp.shape, proj_strain_comp.dtype)



# Assuming proj_strain_comp, angles, and self.psi are defined
# Calculate tensor components with appropriate broadcasting
cos_squared = tf.expand_dims(tf.pow(tf.cos(angles), 2), 1)
sin_squared = tf.expand_dims(tf.pow(tf.sin(angles), 2), 1)
cos_psi_squared = tf.pow(tf.cos(psi), 2)
sin_psi_squared = tf.pow(tf.sin(psi), 2)
sin_2angles = tf.expand_dims(tf.sin(2 * angles), 1)
sin_angles_sin_2psi = tf.expand_dims(tf.sin(angles) * tf.sin(2 * psi), 1)
cos_angles_sin_2psi = tf.expand_dims(tf.cos(angles) * tf.sin(2 * psi), 1)

# Applying the strain equations
proj_strain_ws = (tf.multiply(proj_strain_comp[0], cos_squared * sin_psi_squared) +
                  tf.multiply(proj_strain_comp[1], sin_squared * sin_psi_squared) +
                  tf.multiply(proj_strain_comp[2], cos_psi_squared) +
                  tf.multiply(proj_strain_comp[3], sin_2angles * sin_psi_squared) +
                  tf.multiply(proj_strain_comp[4], sin_angles_sin_2psi) +
                  tf.multiply(proj_strain_comp[5], cos_angles_sin_2psi))


# proj_strain_ws = tf.multiply(proj_strain_comp[0], tf.expand_dims(tf.pow(tf.cos(angles), 2) * tf.pow(tf.sin(psi), 2), 1)) + \
#                  tf.multiply(proj_strain_comp[1], tf.expand_dims(tf.pow(tf.sin(angles), 2) * tf.pow(tf.sin(psi), 2), 1)) + \
#                  tf.multiply(proj_strain_comp[2], tf.pow(tf.cos(psi), 2), 1) + \
#                  tf.multiply(proj_strain_comp[3], tf.expand_dims(tf.sin(2 * angles) * tf.pow(tf.sin(psi), 2), 1)) + \
#                  tf.multiply(proj_strain_comp[4], tf.expand_dims(tf.sin(angles) * tf.sin(2 * psi), 1)) + \
#                  tf.multiply(proj_strain_comp[5], tf.expand_dims(tf.cos(angles) * tf.sin(2 * psi), 1))
# proj_strain_ws = tf.where(thickness > 0.05, proj_strain_ws, 0)
# strain_sino = tf.math.divide_no_nan(proj_strain_ws, thickness)
strain_sino = proj_strain_ws
tifffile.imwrite('/nsls2/users/xyang4/data_tmp/tensor_tomography/strain_sino_tf_3.tiff', strain_sino.numpy())
plt.imshow(strain_sino)
plt.show()
# Out:
# (6, 1, 128, 128)
# (1, 128, 128)
# (1, 128, 128, 1)
# (6, 180, 128) <dtype: 'float32'>
# 2024-05-08 14:45:33.231448: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:33.231764: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:33.231969: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:33.240515: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:33.240735: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:33.240934: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:33.241129: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:33.241317: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:33.241501: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:33.242185: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-08 14:45:33.403305: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:33.403550: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:33.403750: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:33.403942: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:33.404127: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:33.404305: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:33.404483: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:33.404662: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:33.404839: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:34.046942: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:34.047214: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:34.047410: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:34.047585: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:34.047771: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:34.047953: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:34.048143: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:34.048310: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46717 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2024-05-08 14:45:34.048756: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:34.048916: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46696 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2024-05-08 14:45:34.049173: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-08 14:45:34.049331: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46717 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:42:00.0, compute capability: 8.6

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tifffile
from ganrec.propagators import TensorRadon

strain_tensor = np.load('/nsls2/users/xyang4/data_tmp/tensor_tomography/strain_tensor.npy')
# print(strain_tensor.shape)
# plt.imshow(strain_tensor[0,0,:,:])
# plt.show()
num_angles = 180
psi = 90
angles = np.linspace(0, 180, num_angles)
angles = angles * np.pi / 180
psi = psi * np.pi / 180
strain_tensor = tf.cast(strain_tensor, dtype = tf.float32)
strain_tensor = tf.transpose(strain_tensor, [1, 2, 3, 0])
print(strain_tensor.shape)
strain_sino = TensorRadon(strain_tensor, angles, psi).compute()
plt.imshow(strain_sino)
plt.show()
print(strain_sino.shape)
# Out:
# (1, 128, 128, 6)
# vol_mask shape is (1, 128, 128)
# vol_mask shape is (1, 128, 128)
# vol_mask shape is (1, 128, 128, 1)
# vol_mask shape is (1, 128, 128, 1)
# thickness shape is (1, 180, 128, 1)
# thickness shape is (180, 128)
# proj_strain_ws shape is (180, 128)
# (180, 128)

# %%
# Out:
# (6, 1, 128, 128)
# (1, 128, 128, 6)
# proj_strain_ws shape is (180, 128)
# (6, 180, 128)
# 2024-05-07 22:04:32.590285: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:32.590548: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:32.590754: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:32.599205: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:32.599420: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:32.599614: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:32.599799: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:32.599982: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:32.600173: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:32.600868: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-07 22:04:32.747133: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:32.747378: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:32.747575: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:32.747764: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:32.747943: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:32.748124: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:32.748305: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:32.748483: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:32.748664: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:33.391208: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:33.391532: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:33.391729: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:33.391907: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:33.392089: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:33.392256: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:33.392423: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:33.392573: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46717 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2024-05-07 22:04:33.392987: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:33.393138: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46696 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2024-05-07 22:04:33.393396: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-07 22:04:33.393539: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46717 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:42:00.0, compute capability: 8.6

# %%
plt.imshow(strain_sino[0])
plt.show()

# %%
plt.imshow(vol_mask[0,:,:])
plt.show()

# %%
print(vol_mask.numpy().max(), vol_mask.numpy().min())
# Out:
# 1.0 0.0

# %%
thickness = TomoRadon(vol_mask, angles).compute()
print(thickness.shape)
plt.imshow(thickness[0, :, :, 0])
plt.show()
print(thickness.numpy().max(), thickness.numpy().min())
# Out:
# (1, 180, 128, 1)
# 0.6640625 0.0

# %%
thickness = tf.squeeze(thickness)

# %%
tifffile.imwrite('/nsls2/users/xyang4/data_tmp/tensor_tomography/thickness_tf.tiff', thickness.numpy())

# %%
strain_tensor = tf.transpose(strain_tensor, [0, 2, 3, 1])
proj_strain_comp = TomoRadon(strain_tensor, angles).compute()
print(proj_strain_comp.shape)
# Out:
# (6, 180, 128, 1)

# %%
proj_strain_comp = tf.squeeze(proj_strain_comp)
print(proj_strain_comp.shape)
# Out:
# (6, 180, 128)

# %%
tf.multiply(proj_strain_comp[0], tf.expand_dims(tf.pow(tf.cos(angles), 2), 1))
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 tf.multiply(proj_strain_comp[0], tf.expand_dims(tf.pow(tf.cos(angles), 2), 1))
#
# File ~/conda_envs/tf-tomopy/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~/conda_envs/tf-tomopy/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:7164, in raise_from_not_ok_status(e, name)
#    7162 def raise_from_not_ok_status(e, name):
#    7163   e.message += (" name: " + name if name is not None else "")
# -> 7164   raise core._status_to_exception(e) from None
#
# InvalidArgumentError: cannot compute Mul as input #1(zero-based) was expected to be a double tensor but is a float tensor [Op:Mul]

# %%
tf.multiply(proj_strain_comp[0], tf.cast(tf.pow(tf.cos(angles), 2), dtype = tf.float32)*tf.cast(tf.pow(tf.sin(psi), 2), dtype=tf.float32))
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 tf.multiply(proj_strain_comp[0], tf.cast(tf.pow(tf.cos(angles), 2), dtype = tf.float32)*tf.cast(tf.pow(tf.sin(psi), 2), dtype=tf.float32))
#
# File ~/conda_envs/tf-tomopy/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~/conda_envs/tf-tomopy/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:7164, in raise_from_not_ok_status(e, name)
#    7162 def raise_from_not_ok_status(e, name):
#    7163   e.message += (" name: " + name if name is not None else "")
# -> 7164   raise core._status_to_exception(e) from None
#
# InvalidArgumentError: cannot compute Mul as input #1(zero-based) was expected to be a double tensor but is a float tensor [Op:Mul]

# %%
tf.multiply(proj_strain_comp[2], tf.pow(tf.cos(psi), 2), 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 tf.multiply(proj_strain_comp[2], tf.pow(tf.cos(psi), 2), 1)
#
# File ~/conda_envs/tf-tomopy/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~/conda_envs/tf-tomopy/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:7163, in raise_from_not_ok_status(e, name)
#    7162 def raise_from_not_ok_status(e, name):
# -> 7163   e.message += (" name: " + name if name is not None else "")
#    7164   raise core._status_to_exception(e) from None
#
# TypeError: can only concatenate str (not "int") to str

# %%
proj_strain_ws = tf.multiply(proj_strain_comp[0], tf.expand_dims(tf.pow(tf.cos(angles), 2) * tf.pow(tf.sin(psi), 2), 1)) + \
                 tf.multiply(proj_strain_comp[1], tf.expand_dims(tf.pow(tf.sin(angles), 2) * tf.pow(tf.sin(psi), 2), 1)) + \
                 tf.multiply(proj_strain_comp[2], tf.pow(tf.cos(psi), 2), 1) + \
                 tf.multiply(proj_strain_comp[3], tf.expand_dims(tf.sin(2 * angles) * tf.pow(tf.sin(psi), 2), 1)) + \
                 tf.multiply(proj_strain_comp[4], tf.expand_dims(tf.sin(angles) * tf.sin(2 * psi), 1)) + \
                 tf.multiply(proj_strain_comp[5], tf.expand_dims(tf.cos(angles) * tf.sin(2 * psi), 1))
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 proj_strain_ws = tf.multiply(proj_strain_comp[0], tf.expand_dims(tf.pow(tf.cos(angles), 2) * tf.pow(tf.sin(psi), 2), 1)) + \
#       2                  tf.multiply(proj_strain_comp[1], tf.expand_dims(tf.pow(tf.sin(angles), 2) * tf.pow(tf.sin(psi), 2), 1)) + \
#       3                  tf.multiply(proj_strain_comp[2], tf.pow(tf.cos(psi), 2), 1) + \
#       4                  tf.multiply(proj_strain_comp[3], tf.expand_dims(tf.sin(2 * angles) * tf.pow(tf.sin(psi), 2), 1)) + \
#       5                  tf.multiply(proj_strain_comp[4], tf.expand_dims(tf.sin(angles) * tf.sin(2 * psi), 1)) + \
#       6                  tf.multiply(proj_strain_comp[5], tf.expand_dims(tf.cos(angles) * tf.sin(2 * psi), 1))
#
# File ~/conda_envs/tf-tomopy/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~/conda_envs/tf-tomopy/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:7164, in raise_from_not_ok_status(e, name)
#    7162 def raise_from_not_ok_status(e, name):
#    7163   e.message += (" name: " + name if name is not None else "")
# -> 7164   raise core._status_to_exception(e) from None
#
# InvalidArgumentError: cannot compute Mul as input #1(zero-based) was expected to be a double tensor but is a float tensor [Op:Mul]

# %%
tifffile.imwrite('/nsls2/users/xyang4/data_tmp/tensor_tomography/proj_strain_ws_tf.tiff', proj_strain_ws.numpy())

# %%
print(proj_strain_ws.shape)
# Out:
# (180, 128)

# %%
plt.imshow(proj_strain_ws)
plt.show()

# %%
strain_sino = tf.math.divide_no_nan(proj_strain_ws, tfnor_tomo(thickness))
plt.imshow(strain_sino)
plt.show()

# %%
import tifffile
tifffile.imwrite('/nsls2/users/xyang4/data_tmp/tensor_tomography/strain_sino_tf_2.tiff', strain_sino.numpy())
