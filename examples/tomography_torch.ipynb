# %% [markdown]
# # Import necessary modules

# %%
# %matplotlib inline
import numpy as np
import tifffile
import matplotlib.pyplot as plt
import torch
import torch.nn.functional as F
from ganrectorch.utils import angles, nor_tomo
from ganrectorch.propagators import RadonTransform
from ganrectorch.models import make_generator
from ganrectorch.ganrec import GANtomo

# %%
data =tifffile.imread('./test_results/tooth_recon.tiff')
plt.imshow(data)
plt.show()
device = torch.device('cuda')
data = torch.from_numpy(data)
data = data.view(1, 1, 400, 400)
ang = angles(181)

ang = torch.from_numpy(ang)
prj_sim = RadonTransform(data, ang).forward()
# print(prj_sim.shape)
prj_sim = prj_sim.view(181, 400)
prj_sim = prj_sim.numpy()
plt.imshow(prj_sim)
plt.show()

prj = tifffile.imread('./test_data/tooth.tiff')
nang, px = prj.shape
ang = angles(nang)
prj = nor_tomo(prj)
plt.imshow(prj)
plt.show()

# %%
import torch.nn as nn
class Generator(nn.Module):
    def __init__(self, img_h, img_w, conv_num, conv_size, dropout, output_num):
        super(Generator, self).__init__()
        units_out = 128
        self.img_w = img_w
        self.img_h = img_h

        # Calculate the size after the fully connected layers
        input_size = img_w * img_h
        fc_size = img_w**2

        self.fc_stack = nn.Sequential(
            self.dense_norm(input_size, units_out, dropout),
            self.dense_norm(units_out, units_out, dropout),
            self.dense_norm(units_out, units_out, dropout),
            self.dense_norm(units_out, fc_size, 0)
        )

        self.conv_stack = nn.Sequential(
            self.conv2d_norm(1, conv_num, conv_size+2, 1),
            self.conv2d_norm(conv_num, conv_num, conv_size+2, 1),
            self.conv2d_norm(conv_num, conv_num, conv_size, 1),
        )

        self.dconv_stack = nn.Sequential(
            self.dconv2d_norm(conv_num, conv_num, conv_size+2, 1),
            self.dconv2d_norm(conv_num, conv_num, conv_size+2, 1),
            self.dconv2d_norm(conv_num, conv_num, conv_size, 1),
        )

        self.last = nn.Sequential(
            nn.Conv2d(conv_num, output_num, 3, 1, padding='same'),
            nn.Tanh()
        )

    def forward(self, x):
        x = x.view(x.size(0), -1)  # Flatten
        print(x.shape)
        x = self.fc_stack(x)
        x = x.view(-1, 1, self.img_w, self.img_w)  # Reshape to (batch_size, channels, height, width)
        x = self.conv_stack(x)
        x = self.dconv_stack(x)
        x = self.last(x)
        return x

    def dense_norm(self, units_in, units_out, dropout):
        return nn.Sequential(
            nn.Linear(units_in, units_out),
            # nn.BatchNorm1d(units_out),
            nn.ReLU(),
            nn.Dropout(dropout)
        )

    def conv2d_norm(self, in_channels, out_channels, kernel_size, stride):
        return nn.Sequential(
            nn.Conv2d(in_channels, 
                      out_channels, 
                      kernel_size, stride, 
                      padding='same',),
            # nn.BatchNorm2d(out_channels),
            nn.ReLU()
        )

    def dconv2d_norm(self, in_channels, out_channels, kernel_size, stride):
        padding = (kernel_size - 1) // 2
        output_padding = stride-1
        return nn.Sequential(
            nn.ConvTranspose2d(in_channels, 
                               out_channels, 
                               kernel_size, 
                               stride, 
                               padding=padding, 
                               output_padding=output_padding),
            # nn.BatchNorm2d(out_channels),
            nn.ReLU()
        )

# %%
import torch
import torch.nn.functional as F

class TomoRadon:
    def __init__(self, rec, ang):
        self.rec = rec
        self.ang = ang

    def compute(self):
        nang = self.ang.shape[0]
        
        # Transpose the dimensions: (batch, height, width, channels) to (channels, height, width, batch)
        img = self.rec.permute(0, 3, 1, 2)
        
        # Repeat the image nang times along a new dimension at the front
        img = img.repeat(nang, 1, 1, 1)
        
        # Rotate the image
        img = self.rotate(img, -self.ang)
        
        # Compute the mean along the second dimension
        sino = torch.mean(img, dim=1)
        
        # Transpose back and reshape
        sino = sino.permute(2, 0, 1)
        sino = sino.unsqueeze(-1)  # Add a singleton dimension at the end
        
        return sino

    def rotate(self, img, angles):
        batch_size, channels, height, width = img.size()
        
        # Create a batch of rotation matrices
        theta = []
        for angle in angles:
            angle = angle.item()  # Convert tensor to a scalar value
            rotation_matrix = torch.tensor([
                [torch.cos(torch.tensor(angle)), -torch.sin(torch.tensor(angle)), 0],
                [torch.sin(torch.tensor(angle)),  torch.cos(torch.tensor(angle)), 0]
            ])
            theta.append(rotation_matrix)
        theta = torch.stack(theta)  # Stack to create a batch
        
        # Ensure theta has shape [nang, 2, 3]
        theta = theta.to(img.device)  # Move to the same device as img
        print(theta.shape)
        print(img.size())
        # Create the affine grid and apply the rotation to each image
        grid = F.affine_grid(theta, img.size(), align_corners=False)
        img = F.grid_sample(img, grid, mode='bilinear', align_corners=False)
        
        return img

# Example usage
rec = torch.rand(1, 64, 64, 1)  # Example input
ang = torch.tensor([0.0, 0.5, 1.0])  # Example angles
print(ang)

tomoradon = TomoRadon(rec, ang)
sino = tomoradon.compute()
print(sino.shape)
# Out:
# tensor([0.0000, 0.5000, 1.0000])
# torch.Size([3, 2, 3])
# torch.Size([3, 1, 64, 64])
# torch.Size([64, 3, 64, 1])

# %% [markdown]
# # Read the data

# %%
prj = tifffile.imread('./test_data/tooth.tiff')
nang, px = prj.shape
ang = angles(nang)
prj = nor_tomo(prj)
prj = torch.from_numpy(prj)
prj = prj.view(-1, 1, nang, px)
generator = Generator(181, 400, 32, 3, 0.25, 1)
data = generator(prj)
# Out:
# torch.Size([1, 72400])

# %%
print(data.shape)
# Out:
# torch.Size([1, 1, 400, 400])

# %%
prj = tifffile.imread('./test_data/tooth.tiff')
nang, px = prj.shape
ang = angles(nang)
prj = nor_tomo(prj)
# prj = np.reshape(prj, (181, 1, 400))
plt.imshow(prj)
plt.show()
rec = GANtomo(prj, ang, iter_num=1000).recon()
plt.imshow(rec)
plt.show()
tifffile.imwrite('./test_results/recon_tooth', rec)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 8
#       6 plt.imshow(prj)
#       7 plt.show()
# ----> 8 rec = GANtomo(prj, ang, iter_num=1000).recon()
#       9 plt.imshow(rec)
#      10 plt.show()
#
# File ~/ganrec/ganrectorch/ganrec.py:117, in GANtomo.recon(self)
#     115 # prj = self.tfnor_tomo(prj)
#     116 ang = torch.from_numpy(self.angle)
# --> 117 self.make_model()
#     118 if self.init_wpath:
#     119     self.generator.load_state_dict(torch.load(self.init_wpath+'generator.pth'))
#
# File ~/ganrec/ganrectorch/ganrec.py:80, in GANtomo.make_model(self)
#      73 def make_model(self):
#      74     self.generator = Generator(self.prj_input.shape[0],
#      75                                self.prj_input.shape[1],
#      76                                self.conv_num,
#      77                                self.conv_size,
#      78                                self.dropout,
#      79                                1)
# ---> 80     self.discriminator = Discriminator(self.prj_input.shape[0],
#      81                                        self.prj_input.shape[1])
#      82     self.generator_optimizer = optim.Adam(self.generator.parameters(), lr=self.g_learning_rate)
#      83     self.discriminator_optimizer = optim.Adam(self.discriminator.parameters(), lr=self.d_learning_rate)
#
# File ~/ganrec/ganrectorch/models.py:67, in Discriminator.__init__(self, nang, px)
#      64 def __init__(self, nang, px):
#      65     super(Discriminator, self).__init__()
#      66     self.main = nn.Sequential(
# ---> 67         nn.Conv2d(1, 16, (5, 5), stride=(2, 2), padding='same'),
#      68         nn.Conv2d(16, 16, (5, 5), stride=(1, 1), padding='same'),
#      69         nn.LeakyReLU(0.2),
#      70         nn.Dropout(0.2),
#      71
#      72         nn.Conv2d(16, 32, (5, 5), stride=(2, 2), padding='same'),
#      73         nn.Conv2d(32, 32, (5, 5), stride=(1, 1), padding='same'),
#      74         nn.LeakyReLU(0.2),
#      75         nn.Dropout(0.2),
#      76
#      77         nn.Conv2d(32, 64, (3, 3), stride=(2, 2), padding='same'),
#      78         nn.Conv2d(64, 64, (3, 3), stride=(1, 1), padding='same'),
#      79         nn.LeakyReLU(0.2),
#      80         nn.Dropout(0.2),
#      81
#      82         nn.Conv2d(64, 128, (3, 3), stride=(2, 2), padding='same'),
#      83         nn.Conv2d(128, 128, (3, 3), stride=(1, 1), padding='same'),
#      84         nn.LeakyReLU(0.2),
#      85         nn.Dropout(0.2),
#      86
#      87         nn.Flatten(),
#      88         nn.Linear(nang * px * 128, 256),
#      89         nn.Linear(256, 128),
#      90     )
#
# File ~/conda_envs/ganrec/lib/python3.11/site-packages/torch/nn/modules/conv.py:447, in Conv2d.__init__(self, in_channels, out_channels, kernel_size, stride, padding, dilation, groups, bias, padding_mode, device, dtype)
#     445 padding_ = padding if isinstance(padding, str) else _pair(padding)
#     446 dilation_ = _pair(dilation)
# --> 447 super().__init__(
#     448     in_channels, out_channels, kernel_size_, stride_, padding_, dilation_,
#     449     False, _pair(0), groups, bias, padding_mode, **factory_kwargs)
#
# File ~/conda_envs/ganrec/lib/python3.11/site-packages/torch/nn/modules/conv.py:98, in _ConvNd.__init__(self, in_channels, out_channels, kernel_size, stride, padding, dilation, transposed, output_padding, groups, bias, padding_mode, device, dtype)
#      95         raise ValueError(
#      96             f"Invalid padding string {padding!r}, should be one of {valid_padding_strings}")
#      97     if padding == 'same' and any(s != 1 for s in stride):
# ---> 98         raise ValueError("padding='same' is not supported for strided convolutions")
#     100 valid_padding_modes = {'zeros', 'reflect', 'replicate', 'circular'}
#     101 if padding_mode not in valid_padding_modes:
#
# ValueError: padding='same' is not supported for strided convolutions

# %% [markdown]
# # Reconstruct the data with the ganrec algorithm

# %% [markdown]
# # Test for ganrec torch

# %%
from pyinstrument import Profiler
import numpy as np
import tifffile
import matplotlib.pyplot as plt
from ganrectorch.utils import angles, nor_tomo
from ganrectorch.ganrec import GANtomo
profiler = Profiler()
profiler.start()
prj = tifffile.imread('./test_data/tooth.tiff')
nang, px = prj.shape
ang = angles(nang)
prj = nor_tomo(prj)
rec = GANtomo(prj, ang, iter_num=1000).recon()
plt.imshow(rec)
plt.show()
tifffile.imwrite('./test_results/recon_tooth', rec)
profiler.stop()
    
    # Print the profiling results 
print(profiler.output_text(unicode=True, color=True))
# Out:
# Reconstruction Progress: 100%|██████████| 1000/1000 [01:09<00:00, 14.37it/s, D_loss=0.659, G_loss=2.01]
#   _     ._   __/__   _ _  _  _ _/_   Recorded: 12:02:43  Samples:  38386
#  /_//_/// /_\ / //_// / //_'/ //     Duration: 70.251    CPU time: 69.898
# /   _/                      v4.6.2
#
# Program: /nsls2/users/xyang4/conda_envs/ganrec/lib/python3.11/site-packages/ipykernel_launcher.py --f=/nsls2/users/xyang4/.local/share/jupyter/runtime/kernel-v2-2355875boDNtmzWi2lv.json
#
# 70.250 <module>  ../../../../../tmp/ipykernel_2542515/1914615220.py:1
# └─ 70.116 GANtomo.recon  ../ganrectorch/ganrec.py:169
#    ├─ 63.331 _fn  torch/_dynamo/eval_frame.py:428
#    │  └─ 63.286 GANtomo.recon_step  ../ganrectorch/ganrec.py:137
#    │     └─ 63.194 torch_dynamo_resume_in_recon_step_at_139  ../ganrectorch/ganrec.py:139
#    │        ├─ 51.076 torch_dynamo_resume_in_recon_step_at_140  ../ganrectorch/ganrec.py:140
#    │        │  ├─ 46.468 torch_dynamo_resume_in_recon_step_at_150  ../ganrectorch/ganrec.py:150
#    │        │  │  └─ 45.701 torch_dynamo_resume_in_recon_step_at_151  ../ganrectorch/ganrec.py:151
#    │        │  │     └─ 45.634 torch_dynamo_resume_in_recon_step_at_154  ../ganrectorch/ganrec.py:154
#    │        │  │        ├─ 38.313 torch_dynamo_resume_in_recon_step_at_154  ../ganrectorch/ganrec.py:154
#    │        │  │        │  └─ 38.284 torch_dynamo_resume_in_recon_step_at_155  ../ganrectorch/ganrec.py:155
#    │        │  │        │     ├─ 34.266 torch_dynamo_resume_in_recon_step_at_155  ../ganrectorch/ganrec.py:155
#    │        │  │        │     │  ├─ 24.193 GradScaler.step  torch/amp/grad_scaler.py:354
#    │        │  │        │     │  │     [128 frames hidden]  torch, <built-in>, contextlib, <string>
#    │        │  │        │     │  │        1.951 PyCodeCache.load_by_key_path  torch/_inductor/codecache.py:2139
#    │        │  │        │     │  │        └─ 1.943 <module>  ../../../../../tmp/torchinductor_xyang4/yb/cybvkgv66morcnme2gc7npsoarnt4ug3fmipwofrkbvhncmtqtnk.py:1
#    │        │  │        │     │  │           └─ 1.943 AsyncCompile.wait  torch/_inductor/codecache.py:2696
#    │        │  │        │     │  │                 [5 frames hidden]  torch, concurrent, threading, <built-in>
#    │        │  │        │     │  └─ 10.045 torch_dynamo_resume_in_recon_step_at_158  ../ganrectorch/ganrec.py:158
#    │        │  │        │     │     └─ 10.010 GradScaler.step  torch/amp/grad_scaler.py:354
#    │        │  │        │     │           [55 frames hidden]  torch, contextlib, <built-in>
#    │        │  │        │     │              1.853 PyCodeCache.load_by_key_path  torch/_inductor/codecache.py:2139
#    │        │  │        │     │              └─ 1.849 <module>  ../../../../../tmp/torchinductor_xyang4/yj/cyjpwnqmjznns7c6lm5rirjdz7khukfjqkzgjxycajztak4nh4qf.py:1
#    │        │  │        │     │                 └─ 1.849 AsyncCompile.wait  torch/_inductor/codecache.py:2696
#    │        │  │        │     │                       [5 frames hidden]  torch, concurrent, threading, <built-in>
#    │        │  │        │     └─ 3.987 Tensor.backward  torch/_tensor.py:466
#    │        │  │        │           [4 frames hidden]  torch, <built-in>
#    │        │  │        └─ 7.288 Tensor.backward  torch/_tensor.py:466
#    │        │  │              [4 frames hidden]  torch, <built-in>
#    │        │  ├─ 3.613 _fn  torch/_dynamo/eval_frame.py:428
#    │        │  │     [13 frames hidden]  torch
#    │        │  │        3.444 _run_from_cache  torch/_inductor/codecache.py:917
#    │        │  │        └─ 3.443 call  ../../../../../tmp/torchinductor_xyang4/ra/cra4thpprl6ky27xbvcoxtdp6rw7flsn7cqztvbu5lsw2eah4adf.py:3161
#    │        │  │           ├─ 1.366 CachingAutotuner.run  torch/_inductor/triton_heuristics.py:630
#    │        │  │           │     [2 frames hidden]  torch, <string>
#    │        │  │           └─ 0.969 _VariableFunctionsClass.convolution  <built-in>
#    │        │  └─ 0.815 generator_loss  ../ganrectorch/ganrec.py:47
#    │        └─ 12.022 catch_errors  torch/_dynamo/convert_frame.py:871
#    │              [87 frames hidden]  torch, contextlib
#    │                 0.925 PyCodeCache.load_by_key_path  torch/_inductor/codecache.py:2139
#    │                 └─ 0.917 <module>  ../../../../../tmp/torchinductor_xyang4/ra/cra4thpprl6ky27xbvcoxtdp6rw7flsn7cqztvbu5lsw2eah4adf.py:1
#    │                    └─ 0.908 AsyncCompile.wait  torch/_inductor/codecache.py:2696
#    │                          [2 frames hidden]  torch
#    ├─ 5.032 RECONmonitor.update_plot  ../ganrectorch/utils.py:122
#    │  └─ 4.306 display  IPython/core/display_functions.py:105
#    │        [39 frames hidden]  IPython, decorator, matplotlib, PIL, ...
#    └─ 1.187 tqdm.set_postfix  tqdm/std.py:1402
#          [10 frames hidden]  tqdm, ipykernel, threading, <built-in>

# %%
from pyinstrument import Profiler
import numpy as np
import tifffile
import matplotlib.pyplot as plt
from ganrectorch.utils import angles, nor_tomo
from ganrectorch.ganrec import GANtomo
profiler = Profiler()
profiler.start()
prj = tifffile.imread('./test_data/tooth.tiff')
nang, px = prj.shape
ang = angles(nang)
prj = nor_tomo(prj)
rec = GANtomo(prj, ang, iter_num=1000).recon()
plt.imshow(rec)
plt.show()
tifffile.imwrite('./test_results/recon_tooth.tiff', rec)
profiler.stop()
    
    # Print the profiling results 
print(profiler.output_text(unicode=True, color=True))
# Out:
# Iteration 1000: G_loss is nan and D_loss is nan
#   _     ._   __/__   _ _  _  _ _/_   Recorded: 16:51:33  Samples:  34682
#  /_//_/// /_\ / //_// / //_'/ //     Duration: 61.531    CPU time: 61.509
# /   _/                      v4.6.2
#
# Program: /nsls2/users/xyang4/conda_envs/ganrec/lib/python3.11/site-packages/ipykernel_launcher.py --f=/nsls2/users/xyang4/.local/share/jupyter/runtime/kernel-v2-1186749Artw9ax9UHpX.json
#
# 61.530 <module>  ../../../../../tmp/ipykernel_1328420/1091797216.py:1
# └─ 61.397 GANtomo.recon  ../ganrectorch/ganrec.py:168
#    ├─ 55.054 _fn  torch/_dynamo/eval_frame.py:428
#    │  └─ 55.053 GANtomo.recon_step  ../ganrectorch/ganrec.py:136
#    │     └─ 55.020 torch_dynamo_resume_in_recon_step_at_138  ../ganrectorch/ganrec.py:138
#    │        ├─ 46.072 torch_dynamo_resume_in_recon_step_at_139  ../ganrectorch/ganrec.py:139
#    │        │  ├─ 42.094 torch_dynamo_resume_in_recon_step_at_149  ../ganrectorch/ganrec.py:149
#    │        │  │  └─ 42.045 torch_dynamo_resume_in_recon_step_at_150  ../ganrectorch/ganrec.py:150
#    │        │  │     └─ 42.029 torch_dynamo_resume_in_recon_step_at_153  ../ganrectorch/ganrec.py:153
#    │        │  │        ├─ 35.914 torch_dynamo_resume_in_recon_step_at_153  ../ganrectorch/ganrec.py:153
#    │        │  │        │  └─ 35.914 torch_dynamo_resume_in_recon_step_at_154  ../ganrectorch/ganrec.py:154
#    │        │  │        │     ├─ 32.063 torch_dynamo_resume_in_recon_step_at_154  ../ganrectorch/ganrec.py:154
#    │        │  │        │     │  ├─ 21.778 GradScaler.step  torch/amp/grad_scaler.py:354
#    │        │  │        │     │  │     [128 frames hidden]  torch, <built-in>, contextlib, <string>
#    │        │  │        │     │  │        12.833 Tensor.item  <built-in>
#    │        │  │        │     │  └─ 10.286 torch_dynamo_resume_in_recon_step_at_157  ../ganrectorch/ganrec.py:157
#    │        │  │        │     │     └─ 10.286 GradScaler.step  torch/amp/grad_scaler.py:354
#    │        │  │        │     │           [108 frames hidden]  torch, contextlib, <string>, <built-in>
#    │        │  │        │     └─ 3.851 Tensor.backward  torch/_tensor.py:466
#    │        │  │        │           [4 frames hidden]  torch, <built-in>
#    │        │  │        └─ 6.113 Tensor.backward  torch/_tensor.py:466
#    │        │  │              [4 frames hidden]  torch, <built-in>
#    │        │  └─ 3.739 _fn  torch/_dynamo/eval_frame.py:428
#    │        │        [13 frames hidden]  torch
#    │        │           2.896 _run_from_cache  torch/_inductor/codecache.py:917
#    │        │           └─ 2.884 call  ../../../../../tmp/torchinductor_xyang4/ra/cra4thpprl6ky27xbvcoxtdp6rw7flsn7cqztvbu5lsw2eah4adf.py:3161
#    │        │              ├─ 1.041 CachingAutotuner.run  torch/_inductor/triton_heuristics.py:630
#    │        │              │     [2 frames hidden]  torch, <string>
#    │        │              └─ 0.828 _VariableFunctionsClass.convolution  <built-in>
#    │        └─ 8.909 catch_errors  torch/_dynamo/convert_frame.py:871
#    │              [92 frames hidden]  torch, contextlib
#    └─ 5.933 RECONmonitor.update_plot  ../ganrectorch/utils.py:109
#       ├─ 4.217 display  IPython/core/display_functions.py:105
#       │     [39 frames hidden]  IPython, decorator, matplotlib, PIL, ...
#       └─ 1.555 pause  matplotlib/pyplot.py:728
#             [2 frames hidden]  matplotlib, <built-in>

# %%
from pyinstrument import Profiler
import numpy as np
import tifffile
import matplotlib.pyplot as plt
from ganrectorch.utils import angles, nor_tomo
from ganrectorch.ganrec import GANtomo
profiler = Profiler()
profiler.start()
prj = tifffile.imread('./test_data/tooth.tiff')
nang, px = prj.shape
ang = angles(nang)
prj = nor_tomo(prj)
rec = GANtomo(prj, ang, iter_num=1000, g_learning_rate=1e-2, d_learning_rate=1e-3).recon()
plt.imshow(rec)
plt.show()
tifffile.imwrite('./test_results/recon_tooth', rec)
profiler.stop()
    
    # Print the profiling results 
print(profiler.output_text(unicode=True, color=True))
# Out:
# Iteration 1000: G_loss is 1.2879925966262817 and D_loss is 0.8234661221504211
#   _     ._   __/__   _ _  _  _ _/_   Recorded: 11:20:27  Samples:  34370
#  /_//_/// /_\ / //_// / //_'/ //     Duration: 64.845    CPU time: 63.647
# /   _/                      v4.6.2
#
# Program: /nsls2/users/xyang4/conda_envs/ganrec/lib/python3.11/site-packages/ipykernel_launcher.py --f=/nsls2/users/xyang4/.local/share/jupyter/runtime/kernel-v2-3372429QPQu4dz8AwIe.json
#
# 64.844 <module>  ../../../../../tmp/ipykernel_3697580/3107405088.py:1
# └─ 64.711 GANtomo.recon  ../ganrectorch/ganrec.py:190
#    ├─ 58.408 _fn  torch/_dynamo/eval_frame.py:428
#    │     [43 frames hidden]  torch, contextlib
#    │        56.677 GANtomo.recon_step  ../ganrectorch/ganrec.py:160
#    │        └─ 56.636 torch_dynamo_resume_in_recon_step_at_162  ../ganrectorch/ganrec.py:162
#    │           ├─ 46.969 torch_dynamo_resume_in_recon_step_at_163  ../ganrectorch/ganrec.py:163
#    │           │  ├─ 42.814 torch_dynamo_resume_in_recon_step_at_171  ../ganrectorch/ganrec.py:171
#    │           │  │  ├─ 41.119 torch_dynamo_resume_in_recon_step_at_172  ../ganrectorch/ganrec.py:172
#    │           │  │  │  └─ 41.084 torch_dynamo_resume_in_recon_step_at_175  ../ganrectorch/ganrec.py:175
#    │           │  │  │     ├─ 34.855 torch_dynamo_resume_in_recon_step_at_175  ../ganrectorch/ganrec.py:175
#    │           │  │  │     │  └─ 34.824 torch_dynamo_resume_in_recon_step_at_176  ../ganrectorch/ganrec.py:176
#    │           │  │  │     │     ├─ 30.972 torch_dynamo_resume_in_recon_step_at_176  ../ganrectorch/ganrec.py:176
#    │           │  │  │     │     │  ├─ 22.586 GradScaler.step  torch/amp/grad_scaler.py:354
#    │           │  │  │     │     │  │     [93 frames hidden]  torch, <built-in>, contextlib, <string>
#    │           │  │  │     │     │  │        1.848 PyCodeCache.load_by_key_path  torch/_inductor/codecache.py:2139
#    │           │  │  │     │     │  │        └─ 1.841 <module>  ../../../../../tmp/torchinductor_xyang4/zs/czsgrbt2udzvzhglp3fyul27dzjooa6c2x3id7ywiouugnwv74ai.py:1
#    │           │  │  │     │     │  │           └─ 1.841 AsyncCompile.wait  torch/_inductor/codecache.py:2696
#    │           │  │  │     │     │  │                 [5 frames hidden]  torch, concurrent, threading, <built-in>
#    │           │  │  │     │     │  └─ 8.356 torch_dynamo_resume_in_recon_step_at_179  ../ganrectorch/ganrec.py:179
#    │           │  │  │     │     │     └─ 8.321 GradScaler.step  torch/amp/grad_scaler.py:354
#    │           │  │  │     │     │           [51 frames hidden]  torch, <built-in>, contextlib
#    │           │  │  │     │     │              1.211 PyCodeCache.load_by_key_path  torch/_inductor/codecache.py:2139
#    │           │  │  │     │     │              └─ 1.207 <module>  ../../../../../tmp/torchinductor_xyang4/6l/c6lfmoflmsqz4omhtqcxs7pxqrki2ilszg2e46otgnsv54fzryog.py:1
#    │           │  │  │     │     │                 └─ 1.207 AsyncCompile.wait  torch/_inductor/codecache.py:2696
#    │           │  │  │     │     │                       [5 frames hidden]  torch, concurrent, threading, <built-in>
#    │           │  │  │     │     └─ 3.822 Tensor.backward  torch/_tensor.py:466
#    │           │  │  │     │           [4 frames hidden]  torch, <built-in>
#    │           │  │  │     └─ 6.200 Tensor.backward  torch/_tensor.py:466
#    │           │  │  │           [4 frames hidden]  torch, <built-in>
#    │           │  │  └─ 1.549 _fn  torch/_dynamo/eval_frame.py:428
#    │           │  │     └─ 1.190 discriminator_loss  ../ganrectorch/ganrec.py:31
#    │           │  └─ 3.457 _fn  torch/_dynamo/eval_frame.py:428
#    │           │        [13 frames hidden]  torch
#    │           │           3.426 _run_from_cache  torch/_inductor/codecache.py:917
#    │           │           └─ 3.425 call  ../../../../../tmp/torchinductor_xyang4/uy/cuyoipgc4wrjts4fw3sjxcaorberz6eertykt3sjqpoxxgyahit6.py:2630
#    │           │              ├─ 1.481 CachingAutotuner.run  torch/_inductor/triton_heuristics.py:630
#    │           │              │     [2 frames hidden]  torch, <string>
#    │           │              └─ 0.974 _VariableFunctionsClass.convolution  <built-in>
#    │           └─ 9.663 catch_errors  torch/_dynamo/convert_frame.py:871
#    │                 [82 frames hidden]  torch, contextlib
#    │                    0.857 PyCodeCache.load_by_key_path  torch/_inductor/codecache.py:2139
#    │                    └─ 0.850 <module>  ../../../../../tmp/torchinductor_xyang4/uy/cuyoipgc4wrjts4fw3sjxcaorberz6eertykt3sjqpoxxgyahit6.py:1
#    │                       └─ 0.847 AsyncCompile.wait  torch/_inductor/codecache.py:2696
#    │                             [2 frames hidden]  torch
#    └─ 5.787 RECONmonitor.update_plot  ../ganrectorch/utils.py:109
#       ├─ 4.137 display  IPython/core/display_functions.py:105
#       │     [39 frames hidden]  IPython, decorator, matplotlib, PIL, ...
#       └─ 1.534 pause  matplotlib/pyplot.py:728
#             [2 frames hidden]  matplotlib, <built-in>
